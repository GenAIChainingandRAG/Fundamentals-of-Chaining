# %% [markdown]
# ![Blog Post Lab](../assets/complex-tasks.png)
#
# # Blog Post Lab
#
# ---

# %% [markdown]
# ### Learning objective:
# By the end of this lesosn, you will be able to utilize list generation, task decomposition, and multiple chains to build a complex project.
#
#
# ### About:
# This is a lab serves as practical review for prior Langchain and Prompt engineering modules where students will build a blog post.
#
#
#
# ### Prerequisites:
# - Python (required)
# - Intro to LangChain and prior prompt  eng. lessons (required)
# - Visual Studio Code (recommended)
# - GitHub Copilot lessons (recommended)

# %% [markdown]
# ### Contents
# 1. [Imports](#imports)
#
#
# ### Activities
# 1. [Lab](#lab)

# %% [markdown]
# <a id='imports'></a>
# ## Imports

# %%
#basic chains
from langchain_openai import ChatOpenAI #openai chatbot
from langchain_core.prompts import ChatPromptTemplate #template for chat prompts
from langchain_core.output_parsers import StrOutputParser #output parser for string output 

#documents 
from langchain_core.documents import Document
from langchain.chains.combine_documents import create_stuff_documents_chain

#debug
from langchain.globals import set_debug

#display 
from IPython.display import display, Markdown

# %% [markdown]
# <a id='lab'></a>
# ## Lab
#
# #### Build a series of at least 3 chains that generates a series of blog posts for a given users using the following steps:
# 1. Generate a user profile in the style of the profiles below,
# 1. Loads the user profile into a new chain and generate a top 3 destinations list for that traveler.
# 1. Then pass those destinations to a new model generating a custom travel blog for that user.
# 1. Bonus! translate your blog post to a new language or change to a style of your choice.
#
# #### Tips
# - Try editing the system persona and instructions
# - Edit your prompt to observe impact on output
# - Consider using debug
# - Remember to build iteratively testing each chain
#
# #### Plan
#
# chain|chain type| input | output
# --|--|--| --|
# profile_chain | create_stuff_documents_chain | user_profiles doc | new user-profile
# top_three_chain | custom basic chain | user profile | top 3 list
# blog_chain | custom basic chain |  top 3 list | blog post
# bonus_chain | custom basic chain | blog post | tranlation or new style

# %% [markdown]
# #### Sample User Profile Documents

# %%
# Generated by GPT
user_profiles = [
    Document(page_content="Sarah likes solo adventure travel"),
    Document(page_content="Juana loves group trips by motorcoach but doesn't like to fly"),
    Document(page_content="Mike enjoys family vacations at all-inclusive resorts but doesn't like camping"),
    Document(page_content="Emma loves luxury cruises but isn't a fan of backpacking trips"),
    Document(page_content="John prefers cultural immersion travel experiences but doesn't enjoy touristy destinations"),
    Document(page_content="Liam enjoys wildlife safaris but doesn't like crowded cities"),
    Document(page_content="Olivia loves exploring local cuisines but isn't a fan of adventure sports"),
    Document(page_content="Sophia enjoys historical tours but doesn't like beach vacations"),
    Document(page_content="Mason loves hiking and camping but isn't a fan of luxury resorts"),
    Document(page_content="Ava enjoys solo trips to offbeat destinations but doesn't like group tours")
]

# %% [markdown]
# #### Set model

# %%
model = ChatOpenAI(openai_api_key="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", model="gpt-4-0125-preview")

# %% [markdown]
# ### Chain 1: profile_chain
# Use create_stuff_documents_chain to load family_docs and generate a vacation destination

# %%
# add your code here!
prompt = ChatPromptTemplate.from_messages(
    [("system", "Generate a new user-profile for a travel blog in the style of {context}.")]
)
llm = ChatOpenAI(openai_api_key="...", model="gpt-4-0125-preview")
profile_chain = create_stuff_documents_chain(llm, prompt)

# build iteratively and test along the way 
profile_chain.invoke({"context": user_profiles})
# Out:
# '**User Profile: Ava**\n\n**Bio:** Ava\'s wanderlust spirit has taken her to the less trodden paths of the world. With a keen eye for the unique and undiscovered, she thrives on the thrill of solo travel. Ava isn\'t one to follow the crowd—instead, she crafts her own adventures, seeking out destinations that are off the beaten path. Her travel philosophy centers around the belief that the most memorable experiences come from the unexpected encounters and hidden gems found only by venturing solo.\n\n**Travel Preferences:** Ava\'s journey is marked by a penchant for solo trips to places that are not on every tourist\'s radar. She believes in immersing herself fully in the culture and life of the places she visits, favoring interactions with locals over guided group tours. Her adventures are carefully curated to ensure a blend of serenity, cultural enrichment, and personal growth.\n\n**Dislikes:** While Ava respects the appeal of group tours for many travelers, she finds that they often
# ...

# %% [markdown]
# ### Chain 2: top_three_chain
# Build a new chain to generate a top 3 location list for this traveler.

# %%
# add your code here!
prompt2 = ChatPromptTemplate.from_template(
    "Generate a list of 3 vacation destinations that would be a good fit for a user with the following profile: {user-profile}. Only output destinations in the format: 1. New York, USA 2. Rome, Italy 3. Bogota, Columbia"
)
top_three_chain = (
    {"user-profile": profile_chain} 
    | prompt2
    | model
    | StrOutputParser()
)

# build iteratively and test along the way 
top_three_chain.invoke({"context": user_profiles})
# Out:
# '1. Kyrgyzstan, Central Asia  \n2. Faroe Islands, Denmark  \n3. Svalbard, Norway'

# %% [markdown]
# ### Chain 3: blog_chain
# Generate a custom blog post for this user and the recommended destinations.

# %%
# add your code here!
prompt3 = ChatPromptTemplate.from_template(
    "Write travel blog post on {destinations}. Highlight why someone would want to visit that location and key attractions."
)
blog_chain = (
    {"destinations": top_three_chain } 
    | prompt3
    | model
    | StrOutputParser()
)

# build iteratively and test along the way 
blog_chain.invoke({"context": user_profiles})
# Out:
# "# Discovering Hidden Gems: Bhutan, Faroe Islands, and Svalbard\n\nFrom the mystical heights of the Himalayas to the rugged coastlines of the North Atlantic, our planet is peppered with destinations that seem to defy reality. For those yearning to step off the beaten path and embrace the extraordinary, Bhutan, the Faroe Islands, and Svalbard represent three corners of the world where adventure and awe await at every turn. Let's embark on a journey to these hidden gems, exploring why they should top your travel bucket list.\n\n## Bhutan: The Last Shangri-La\n\nNestled in the heart of the Himalayas, Bhutan is a country where happiness is more than a feeling—it's a way of life. Known as the last Shangri-La, this kingdom has embraced modernity without letting go of its mystical past, making it a must-visit for those seeking a blend of tranquility and adventure.\n\n### Why Visit Bhutan?\n\n- **Gross National Happiness:** Bhutan is the only country in the world that measures its progress t
# ...

# %% [markdown]
# ### Iterate!
# Edit prompts and chains until you are happy with the output.

# %% [markdown]
# ### Bonus Examples
# 1. New system persona for the blog post
# 1. Translate to new language
# 1. New style

# %%
# add your code here!
# poet persona 
prompt3 = ChatPromptTemplate.from_messages(
    [("system", "You are helpful and well traveled poet") ,
     ("user", "Write travel blog post on {destinations}. Highlight why someone would want to visit that location and key attractions.")
 ])
    
blog_chain = (
    {"destinations": top_three_chain } 
    | prompt3
    | model
    | StrOutputParser()
)

# build iteratively and test along the way 
blog_chain.invoke({"context": user_profiles})
# Out:
# '# Discovering the World\'s Hidden Gems: Socotra, Svalbard, and Bhutan\n\nIn a world that often seems fully mapped, digitized, and dissected, there are still places that manage to slip through the cracks of mass tourism, retaining their enigmatic allure and untouched beauty. Among these hidden gems, Socotra Island in Yemen, Svalbard in Norway, and the kingdom of Bhutan in Asia stand out as destinations that promise not just travel, but a journey into the unknown, each offering unique experiences that are as diverse as they are profound.\n\n## Socotra Island, Yemen: The Alien Island of Earthly Wonders\n\nNestled in the Arabian Sea, Socotra Island is often described as the most alien-looking place on Earth, and for good reason. Its surreal landscapes are home to flora and fauna found nowhere else on the planet. The Dragon Blood Tree, with its umbrella-shaped canopy and red sap, is perhaps the island\'s most iconic symbol, embodying the essence of Socotra\'s otherworldly charm.\n\n**Why
# ...

# %%
# Translate 
# add your code here!
prompt4 = ChatPromptTemplate.from_template(
    "Translate {blog} to Spanish"
)
translate_chain = (
    {"blog": blog_chain } 
    | prompt4
    | model
    | StrOutputParser()
)

# build iteratively and test along the way 
translate_chain.invoke({"context": user_profiles})
# Out:
# '## Desvelando Joyas Ocultas: Svaneti, Raja Ampat y las Islas Feroe\n\nEn un mundo repleto de destinos turísticos que alardean de su belleza y patrimonio, hay lugares que todavía logran esconderse, ofreciendo experiencias tan únicas y prístinas que se sienten casi de otro mundo. Hoy, nos embarcamos en un viaje hacia tres de estos tesoros: el enigmático Svaneti en Georgia, el paraíso submarino de Raja Ampat en Indonesia y la rugosa belleza de las Islas Feroe en Dinamarca. Cada destino es un universo en sí mismo, prometiendo aventuras y vistas que están destinadas a dejar una marca indeleble en tu alma.\n\n### 1. Svaneti, Georgia: Donde el Tiempo se Detiene\n\nEscondido en el corazón del Cáucaso, Svaneti es una región que el tiempo olvidó. Es un lugar donde antiguas torres salpican el paisaje, actuando como silenciosos centinelas de una era pasada. Svaneti no es solo un destino turístico; es un salto hacia atrás a un pasado medieval, ofreciendo un vistazo a la vida de la gente Svan, in
# ...

# %%
# New Style 
# add your code here!
prompt4 = ChatPromptTemplate.from_template(
    "Convert {blog} to the style of a pirate"
)
style_chain = (
    {"blog": blog_chain } 
    | prompt4
    | model
    | StrOutputParser()
)

# build iteratively and test along the way 
style_chain.invoke({"context": user_profiles})
# Out:
# "## **Voyage to the Uncharted: Tusheti, Georgia; Socotra Isle, Yemen; and Svalbard, Norway**\n\nIn the soul of every sea rover and adventure-seeker beats the heart of discovery, a yearning to chart the uncharted, to traverse the untouched realms of our globe where beauty, adventure, and mystery abide in their purest forms. From the rugged, verdant expanse of Georgia to the otherworldly terrains of Yemen, and the icy wilderness of Norway, this voyage uncovers three of the globe's most secluded and enthralling harbors: Tusheti, Socotra Isle, and Svalbard. Each beckons with a siren's call, challenging the spirit of those daring enough to explore their secrets.\n\n### **Tusheti, Georgia: A Hidden Jewel Amidst the Caucasus**\n\nHidden in the northeastern reaches of Georgia, Tusheti is a breathtaking realm of mountains that whispers tales of yore. Accessible only when the sun blesses the land, through the perilous Abano Pass, Tusheti stands as a sanctuary for adventurers and lovers of the 
# ...

# %% [markdown]
# ### Bonus:
# We can optionally save our outputs and display them. Here was a copy and paste, but variables are recommended.

# %%
text = '### An Odyssey of Discovery: Tbilisi, Georgia; Valparaíso, Chile; Ljubljana, Slovenia\n\nHoist the sails and chart a course across the vast seas of our globe, me hearties, for we\'re off to uncover treasures hidden in the continents\' heartiest bosoms. Through the bustling streets of Tbilisi, Georgia, down to the art-soaked alleys of Valparaíso, Chile, and across to the serene embrace of Ljubljana, Slovenia, this travel log be a map to the essence of destinations most captivating.\n\n#### Tbilisi, Georgia: A Blend of Warmth and History\n\nIn the clasp of the Mtkvari River, Tbilisi lies with its scenic beauty, cobblestone paths, and the warmest of welcomes, standing proud as a beacon of Georgia\'s rich tales and vibrant culture. A city where the echoes of the past mingle with the whispers of the present, Tbilisi promises a voyage through the annals of time ye won\'t soon forget.\n\n**Why Set Sail?**\nTbilisi be a curious mix of the East and West, clear in its buildings, feasts, and traditions, making it a fascinating port for those in search of adventures untold. The city\'s famed sulfur baths, ancient fortresses, and lively markets offer a peek into its storied past and bustling present.\n\n**Treasures to Uncover:**\n\n- **Narikala Fortress:** Overseeing Tbilisi, this ancient stronghold offers panoramic views of the city and a trek through Georgia\'s medieval history.\n- **Sulfur Baths:** Hidden in the Abanotubani district, these historic baths be a perfect way to relax and experience a crucial part of Tbilisi\'s culture.\n- **Fabrika:** A beacon of creativity, this old Soviet sewing factory now shelters artists\' studios, odd shops, and eclectic cafes.\n\n#### Valparaíso, Chile: A Canvas of Colors and Poetry\n\nPerched upon the Pacific\'s edge, Valparaíso captures the soul with its explosion of colors, steep ascents, and a maze of winding streets. Often dubbed the "Jewel of the Pacific," this UNESCO World Heritage site is a sanctuary for artists, poets, and dreamers.\n\n**Why Set Sail?**\nValparaíso\'s bohemian spirit, paired with its stunning seaside views and colorful street art, makes it a unique port for travelers in pursuit of inspiration and beauty. The city\'s historic funiculars offer a quaint yet thrilling way to explore its many hills and hidden treasures.\n\n**Treasures to Uncover:**\n\n- **Cerro Concepción and Cerro Alegre:** These hills be decked with colorful murals and street art, offering not just stunning visuals but also deep insights into Chilean culture and history.\n- **La Sebastiana:** The former abode of Nobel laureate Pablo Neruda, this museum offers a peek into the life of one of Chile\'s most cherished poets, against the backdrop of breathtaking ocean vistas.\n- **Ascensores:** These historic funicular elevators be a fun and unique way to navigate the city\'s steep terrain while experiencing a piece of Valparaíso\'s heritage.\n\n#### Ljubljana, Slovenia: A Symphony of Green and Culture\n\nLjubljana, the jewel of Slovenia, be a city that radiates charm and tranquility. With its verdant spaces, pedestrian-only city heart, and a river that gently weaves through the city\'s core, Ljubljana is a breath of fresh air for those seeking a peaceful yet culturally rich urban adventure.\n\n**Why Set Sail?**\nLjubljana\'s dedication to sustainability, vibrant cultural scene, and the blend of historic architecture with contemporary art and design make it an enticing destination for eco-conscious travelers and culture lovers alike.\n\n**Treasures to Uncover:**\n\n- **Ljubljana Castle:** Perched atop a hill, this historic castle offers stunning views of the city and a glimpse into Slovenia\'s medieval past.\n- **Tivoli Park:** The city\'s largest green space, perfect for leisurely walks, picnics, and basking in the serenity of nature.\n- **Metelkova Mesto:** An autonomous cultural haven that embodies Ljubljana\'s avant-garde spirit, known for its eclectic architecture, lively nightlife, and community-driven art projects.\n\nThese destinations—Tbilisi, Valparaíso, and Ljubljana—offer a unique tapestry of experiences that call to the soul of every wanderer. From the warm geothermal springs of Tbilisi, the poetic streets of Valparaíso, to the green sanctuaries of Ljubljana, these cities promise adventures not just through space, but through time, culture, and self-discovery. So, weigh anchor, set sail, and let the winds of adventure guide you to these lands afar!'

# %%
from IPython.display import display, Markdown 
display(Markdown(text))
# Out:
# ### An Odyssey of Discovery: Tbilisi, Georgia; Valparaíso, Chile; Ljubljana, Slovenia
#
# Hoist the sails and chart a course across the vast seas of our globe, me hearties, for we're off to uncover treasures hidden in the continents' heartiest bosoms. Through the bustling streets of Tbilisi, Georgia, down to the art-soaked alleys of Valparaíso, Chile, and across to the serene embrace of Ljubljana, Slovenia, this travel log be a map to the essence of destinations most captivating.
#
# #### Tbilisi, Georgia: A Blend of Warmth and History
#
# In the clasp of the Mtkvari River, Tbilisi lies with its scenic beauty, cobblestone paths, and the warmest of welcomes, standing proud as a beacon of Georgia's rich tales and vibrant culture. A city where the echoes of the past mingle with the whispers of the present, Tbilisi promises a voyage through the annals of time ye won't soon forget.
#
# **Why Set Sail?**
# ...
